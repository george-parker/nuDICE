#                                  `7MM"""Yb. `7MMF' .g8"""bgd `7MM"""YMM 
#                                    MM    `Yb. MM .dP'     `M   MM    `7 
#                         `7M'  `MF 'MM     `Mb MM dM'       `   MM   d   
#                           VA  'V   MM      MM MM MM            MMmmMM   
#                            VA ,V   MM     ,MP MM MM.           MM   Y  ,
#                             VVV    MM    ,dP' MM `Mb.     ,'   MM    ,M
#                              W   .JMmmmdP' .JMML. `"bmmmd'  .JMMmmmmMMM
#             
#                          ==================================================
# 
#                          neutrino Decay & Interference Computational Engine
#                               
#                                       based on arXiv:2604.09776
# 
#                           ----------  J.Kopp & G.A.Parker 2026 ----------
# 
#                            * · * · * · * · ROLL THE DICE · * · * · * · *

# %%
import nudice

# %%
# %run plotting

# %%
# %%capture
plt.plot()
# %run plotting

# %%
# this code runs internally with eV so these might be useful
meter = 5.06773093741e6        # [eV^-1/m]
km = 1.0e3*meter               # [eV^-1/km]
MeV = 1.0e6                    # [eV/MeV]

# mass=="NO", nufit 6.1 w/ SK-atms

Delta_m21_sq = 7.537e-5        # [eV^2]
Delta_m31_sq = 2.511e-3        # [eV^2]
theta12 = 33.76*np.pi/180
theta13 = 8.62*np.pi/180
theta23 = 43.29*np.pi/180

U = nudice.Uall(theta12, theta23, theta13, 0)  # lepton mixing matrix (we set delta_CP=0)

# %%
# === Neutrino mass spectrum (Normal Ordering) ===

# for mi -> mj in NO
def mass(m1):
    m2 = np.sqrt(Delta_m21_sq + m1**2)
    m3 = np.sqrt(Delta_m31_sq + m1**2)
    return m2, m3

# %%
decay_purple = (0.3, 0, 0.8)

# %% [markdown]
# # Fig 3.

# %%
print(nudice.dynam.__doc__)
# Out:
#     Solve the Lindblad equation via the dynamical map (this is the default method).
#
#     Applies the dynamical map (obtained from the matrix exponential of the
#     Liouvillian) directly to the vectorized initial state.
#
#     Parameters
#     ----------
#     initial_value (n_bins, Ndim, Ndim) : Initial density matrix in the mass basis, for each energy bin.
#     L                                  : Propagation distance.
#     e_edges (n_bins + 1,)              : Energy bin edges.
#     masses (Ndim,)                     : Neutrino masses (lightest first, doubled for Majorana).
#     g_s(g_ps)                          : Scalar(pseudoscalar) coupling.
#     channel                            : Decay-channel dictionary.  Each entry is a channel with
#                                          indices for both parent and daughter.
#     Returns
#     -------
#     ndarray (n_bins, Ndim, Ndim)       : Evolved density matrix at L, one block per energy bin.

# %%
# PLOT PARAMS
g_s   = 0.5                                                 # scalar coupling 
m1_   = 1e-3                                                # m1 mass in eV
dist  = 100*km                                              # propagation distance                
E_min = 0.                                                  # lowest energy bin lower edge
E_max = 5.*MeV                                              # highest energy bin upper edge
num   = 100                                                 # number of energy bins

# initial state: flat spectrum of pure muon neutrinos in the mass basis
initial_value = nudice.flav_to_mass([[0,0,0],
                                     [0,1,0],
                                     [0,0,0]],U,0) * np.ones(num).reshape(num, 1, 1)

# allowed decay channels (dual decay)
channel = {"n3->n2": { "index_p" : 2,"index_d" : 1},
           "n3->n1": { "index_p" : 2,"index_d" : 0}}

# %%
# calcuate the rest
g_ps  = g_s                                                 # we set g_ps = g_s
m2_, m3_ = mass(m1_)                                        # calculate masses of nu2, nu3
masses   = [m1_, m2_, m3_]
e_edges = np.linspace(E_min, E_max, num+1)                  # energy bin edges
e_centr = 0.5 * (e_edges[1:] + e_edges[:-1])                # energy bin centres

# %%
# run code
with Roll("OQS method", 2):
    answer = nudice.dynam(initial_value, dist, e_edges, masses, g_s, g_ps, channel)
    
# extract flavour information
oqs = nudice.dibloc([nudice.mass_to_flav(k, U, 0) for k in answer])
# Out:
# Output()

# %%
# here is the data from the OWL method, which is not implemented here
owl = np.loadtxt('owl_data.txt')[:,1:]

# %%
owl_plot(e_edges, owl, oqs, g_s, dist, m1_)

# plt.savefig("diff.pdf", dpi=1000)
# plt.show()

# %% [markdown]
# # Fig 4.

# %%
# PLOT PARAMS
g_s   = 0.05                                                # scalar coupling 
m1_   = 1e-3                                                # m1 mass in eV
dist  = 100*km                                              # propagation distance                
E_min = 0.                                                  # lowest energy bin lower edge
E_max = 5.*MeV                                              # highest energy bin upper edge
num   = 100                                                 # number of energy bins

# %%
# calcuate the rest
g_ps  = g_s                                                 # we set g_ps = g_s
m2_, m3_ = mass(m1_)                                        # calculate masses of nu2, nu3
e_edges = np.linspace(E_min, E_max, num+1)                  # energy bin edges
e_centr = 0.5 * (e_edges[1:] + e_edges[:-1])                # energy bin centres

# %%
# run the code
mass_array = []
flav_array = []
init_state = []

masses_list = np.array([m1_, m2_, m3_, 1e-1, 0.2, 0.5])

for N in [3, 4, 5, 6]:

    t0 = time.time()
    with Roll("System with "+str(N)+" neutrinos", N-1):
        
        masses = masses_list[:N]
    
        # turn on all decay channels i->j for i>j
        channel = {}
        for i in range(N):
            for j in range(i):
                channel[f"n{i+1}->n{j+1}"] = {"index_p": i, "index_d": j}

        # mixing matrix - extra flavors decouple
        U_N = np.zeros((N, N), dtype=np.complex128)
        U_N[:3, :3] = nudice.Uall(theta12, theta23, theta13, 0)
        for i in range(3, N):
            U_N[i, i] = 1.0                            

        # initial state: pure heaviest mass eigenstate for each configuration
        rho_mass = np.zeros((N, N), dtype=np.complex128)
        rho_mass[N-1, N-1] = 1.0    
        initial_value = rho_mass * np.ones(num).reshape(num, 1, 1)

        init_state.append(np.tile(np.real(np.diag(rho_mass)), (num, 1)))
        
        answer = nudice.dynam(initial_value, dist, e_edges, masses, g_s, g_ps, channel)
        mass_array.append(nudice.dibloc(answer))
        flav_array.append(nudice.dibloc([nudice.mass_to_flav(k, U_N, 0) for k in answer]))
# Out:
# Output()
# Output()
# Output()
# Output()

# %%
fig, axes = dice_plot(e_edges, mass_array, flav_array, init_state, g_s, dist, masses)

# plt.savefig("dice.pdf", dpi=1000)
# plt.show()

# %% [markdown]
# # Fig. 5

# %%
print(nudice.make_majorana.__doc__)
# Out:
#     Extend a Dirac decay channel dictionary to a Majorana one by doubling the state space.
#
#     The Dirac channel dictionary has keys of the form "nX->nY" (e.g. "n2->n1"), where
#     "n"("a") denotes a neutrino(antineutrino) mass eigenstate. This function produces
#     all four Majorana channels for each Dirac channel:
#
#         nX->nY   (nu -> nu,   helicity-conserving)
#         aX->aY   (anu -> anu, helicity-conserving)
#         nX->aY   (nu -> anu,  helicity-violating)
#         aX->nY   (anu -> nu,  helicity-violating)
#
#     The doubled mass array is [m1, m2, ..., m1, m2, ...], where the first half
#     corresponds to neutrinos and the second half to antineutrinos.
#
#     Parameters
#     ----------
#     masses (Ndim,)                     : Neutrino masses (lightest first).
#     channel                            : Decay-channel dictionary.  Each entry is a channel with
#                                          indices for both parent and daughter.
#
# ...

# %%
# PLOT PARAMS
g_s   = 1e-2                                                # scalar coupling 
m1_   = 1e-3                                                # m1 mass in eV
dist  = 50*km                                               # propagation distance                
E_min = 0.                                                  # lowest energy bin lower edge
E_max = 3.*MeV                                              # highest energy bin upper edge
num   = 200                                                 # number of energy bins

# flat spectrum of pure electron ANTIneutrinos in the mass basis
mass_ebar = nudice.flav_to_mass([[1,0,0],
                                 [0,0,0],
                                 [0,0,0]],U,1) * np.ones(num).reshape(num, 1, 1)

# allowed decay channels (dual decay)
channel = {"n3->n2": { "index_p" : 2,"index_d" : 1},
           "n3->n1": { "index_p" : 2,"index_d" : 0}}

# %%
# calcuate the rest
g_ps  = g_s                                                 # we set g_ps = g_s
m2_, m3_ = mass(m1_)                                        # calculate masses of nu2, nu3
masses = [m1_, m2_, m3_]
Ndim = len(masses)
e_edges = np.linspace(E_min, E_max, num+1)                  # energy bin edges
e_centr = 0.5 * (e_edges[1:] + e_edges[:-1])                # energy bin centres

# %%
# load in an example reactor at 50 km
flux = np.loadtxt('reactor_flux.txt')[:,1]

# %%
# now we extend our system to account for Majorana decays 
initial_maj = np.zeros((num, 2*Ndim, 2*Ndim), dtype=np.complex128)

# initial state: reactor spectrum of pure electron antineutrinos
initial_maj[:, Ndim:, Ndim:] = flux[:, None, None] * mass_ebar
masses_maj, channel_maj = nudice.make_majorana(masses, channel)

# %%
with Roll("Majorana decays at a reactor", 4):
    answer_maj = nudice.dynam(initial_maj, dist, e_edges, masses_maj, g_s, g_ps, channel_maj)
# Out:
# Output()

# %%
# extract and combine the nu and antinu results
result_n = answer_maj[:, :Ndim, :Ndim]
result_a = answer_maj[:, Ndim:, Ndim:]

# mass basis
maj_n_mass = nudice.dibloc(result_n)
maj_a_mass = nudice.dibloc(result_a)
maj_mass_combined = np.concatenate([maj_n_mass, maj_a_mass], axis=-1)

# flav basis
maj_n_flav = nudice.dibloc([nudice.mass_to_flav(k, U, 0) for k in result_n])
maj_a_flav = nudice.dibloc([nudice.mass_to_flav(k, U, 1) for k in result_a])
maj_flav_combined = np.concatenate([maj_n_flav, maj_a_flav], axis=-1)

# %%
maj_plot(e_edges, maj_flav_combined, maj_mass_combined, flux, g_s, dist, m1_)

# plt.savefig("majorana.pdf", dpi=1000)
# plt.show()

# %% [markdown]
# # Fig 6.

# %%
# PLOT PARAMS
g_s   = 0.1                                                 # scalar coupling 
dist = 50*km                                                # propagation distance

# %%
# here is the output for the computation plot, this took ~2 days to run
test_bins = [int(i) for i in(np.geomspace(51,500,9))]
result    = {
'LIND':     [53.84898037500011, 124.97835533300008, 274.8791624160001, 607.9305743750001,
            1323.9004255829996, 2916.303904458, 6493.385421916001, 12963.044011916, 26653.70118725],
'LIOUV':    [3.8434532500000387, 8.53894349999996, 12.428548207999938, 22.602689792000092, 
            39.26225620900004,70.60792250000031, 130.85067258299932, 246.61459904200092, 452.7005010419962]}

# %%
fig, ax = comp_plot(test_bins, result, g_s, dist)

# plt.savefig("scaling.pdf", dpi=1000)
# plt.show()
